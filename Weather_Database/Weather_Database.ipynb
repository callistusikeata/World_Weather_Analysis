# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
lat_lngs

# %%
#Get the nearest city using the citipy module
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 758

# %%
#Perform an API call with the OpenWeatherMap
#Import dependencies
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | torrington
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | vrangel
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | husavik
# Processing Record 8 of Set 1 | brindisi
# Processing Record 9 of Set 1 | laguna
# Processing Record 10 of Set 1 | avera
# Processing Record 11 of Set 1 | clyde river
# Processing Record 12 of Set 1 | pisco
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | tasiilaq
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | hachinohe
# Processing Record 17 of Set 1 | sandwick
# Processing Record 18 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 1 | atuona
# Processing Record 20 of Set 1 | noumea
# Processing Record 21 of Set 1 | bassar
# Processing Record 22 of Set 1 | hilo
# Processing Record 23 of Set 1 | alofi
# Processing Record 24 of Set 1 | barranca
# Processing Record 25 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 1 | muroto
# Processing Record 27 of Set 1 | cidreira
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 30 of Set 1 | mazamitla
# Processing Record 31 of Set 1 | east london
# Processing Record 32 of Set 1 | dingle
# Processing Record 33 of Set 1 | qaanaaq
# Processing Record 34 of Set 1 | port elizabeth
# Processing Record 35 of Set 1 | vanimo
# Processing Record 36 of Set 1 | bodden town
# Processing Record 37 of Set 1 | castro
# Processing Record 38 of Set 1 | rikitea
# Processing Record 39 of Set 1 | busselton
# Processing Record 40 of Set 1 | ponta delgada
# Processing Record 41 of Set 1 | imelda
# Processing Record 42 of Set 1 | avarua
# Processing Record 43 of Set 1 | port alfred
# Processing Record 44 of Set 1 | cape town
# Processing Record 45 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 1 | hobart
# Processing Record 47 of Set 1 | zyryanovsk
# Processing Record 48 of Set 1 | athabasca
# Processing Record 49 of Set 1 | hithadhoo
# Processing Record 50 of Set 1 | cayenne
# Processing Record 1 of Set 2 | barrow
# Processing Record 2 of Set 2 | khatanga
# Processing Record 3 of Set 2 | culasi
# Processing Record 4 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 2 | hermanus
# Processing Record 6 of Set 2 | san vicente
# Processing Record 7 of Set 2 | tiznit
# Processing Record 8 of Set 2 | evensk
# Processing Record 9 of Set 2 | saskylakh
# Processing Record 10 of Set 2 | yingcheng
# Processing Record 11 of Set 2 | mahebourg
# Processing Record 12 of Set 2 | yar-sale
# Processing Record 13 of Set 2 | sena madureira
# Processing Record 14 of Set 2 | haines junction
# Processing Record 15 of Set 2 | hami
# Processing Record 16 of Set 2 | mar del plata
# Processing Record 17 of Set 2 | cedar park
# Processing Record 18 of Set 2 | thinadhoo
# Processing Record 19 of Set 2 | talakan
# Processing Record 20 of Set 2 | tansen
# Processing Record 21 of Set 2 | bredasdorp
# Processing Record 22 of Set 2 | katha
# City not found. Skipping...
# Processing Record 23 of Set 2 | port hedland
# Processing Record 24 of Set 2 | georgetown
# Processing Record 25 of Set 2 | satitoa
# City not found. Skipping...
# Processing Record 26 of Set 2 | iseyin
# Processing Record 27 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 2 | airai
# Processing Record 29 of Set 2 | beringovskiy
# Processing Record 30 of Set 2 | pacific grove
# Processing Record 31 of Set 2 | hamilton
# Processing Record 32 of Set 2 | solvychegodsk
# Processing Record 33 of Set 2 | norman wells
# Processing Record 34 of Set 2 | tual
# Processing Record 35 of Set 2 | tateyama
# Processing Record 36 of Set 2 | pevek
# Processing Record 37 of Set 2 | nome
# Processing Record 38 of Set 2 | namtsy
# Processing Record 39 of Set 2 | adrar
# Processing Record 40 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 2 | hegang
# Processing Record 42 of Set 2 | mandalgovi
# Processing Record 43 of Set 2 | puerto ayora
# Processing Record 44 of Set 2 | nikolskoye
# Processing Record 45 of Set 2 | torbay
# Processing Record 46 of Set 2 | resistencia
# Processing Record 47 of Set 2 | ribeira grande
# Processing Record 48 of Set 2 | hovd
# Processing Record 49 of Set 2 | new norfolk
# Processing Record 50 of Set 2 | porto novo
# Processing Record 1 of Set 3 | jinka
# Processing Record 2 of Set 3 | sao filipe
# Processing Record 3 of Set 3 | gimbi
# Processing Record 4 of Set 3 | axim
# Processing Record 5 of Set 3 | butaritari
# Processing Record 6 of Set 3 | saint-philippe
# Processing Record 7 of Set 3 | tura
# Processing Record 8 of Set 3 | san policarpo
# Processing Record 9 of Set 3 | chuy
# Processing Record 10 of Set 3 | longyearbyen
# Processing Record 11 of Set 3 | faanui
# Processing Record 12 of Set 3 | yatou
# Processing Record 13 of Set 3 | kavaratti
# Processing Record 14 of Set 3 | ardakan
# Processing Record 15 of Set 3 | general roca
# Processing Record 16 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 3 | poing
# Processing Record 18 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 19 of Set 3 | victoria
# Processing Record 20 of Set 3 | bengkulu
# Processing Record 21 of Set 3 | bubaque
# Processing Record 22 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 23 of Set 3 | vestmanna
# Processing Record 24 of Set 3 | kilrush
# Processing Record 25 of Set 3 | provideniya
# Processing Record 26 of Set 3 | port lincoln
# Processing Record 27 of Set 3 | deniliquin
# Processing Record 28 of Set 3 | mananjary
# Processing Record 29 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 30 of Set 3 | yellowknife
# Processing Record 31 of Set 3 | fairbanks
# Processing Record 32 of Set 3 | carnarvon
# Processing Record 33 of Set 3 | rennes
# Processing Record 34 of Set 3 | lebu
# Processing Record 35 of Set 3 | bluff
# Processing Record 36 of Set 3 | grindavik
# Processing Record 37 of Set 3 | road town
# Processing Record 38 of Set 3 | hasaki
# Processing Record 39 of Set 3 | pangnirtung
# Processing Record 40 of Set 3 | bethel
# Processing Record 41 of Set 3 | saldanha
# Processing Record 42 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 43 of Set 3 | vila franca do campo
# Processing Record 44 of Set 3 | silikatnyy
# Processing Record 45 of Set 3 | podgorodnyaya pokrovka
# Processing Record 46 of Set 3 | lukoyanov
# Processing Record 47 of Set 3 | leningradskiy
# Processing Record 48 of Set 3 | ulaangom
# Processing Record 49 of Set 3 | tandil
# Processing Record 50 of Set 3 | kidal
# Processing Record 1 of Set 4 | guerrero negro
# Processing Record 2 of Set 4 | huinan
# Processing Record 3 of Set 4 | linxi
# Processing Record 4 of Set 4 | xining
# Processing Record 5 of Set 4 | ponta do sol
# Processing Record 6 of Set 4 | mancio lima
# Processing Record 7 of Set 4 | upernavik
# Processing Record 8 of Set 4 | naica
# Processing Record 9 of Set 4 | miracema do tocantins
# Processing Record 10 of Set 4 | severo-kurilsk
# Processing Record 11 of Set 4 | san patricio
# Processing Record 12 of Set 4 | gafanha da encarnacao
# Processing Record 13 of Set 4 | wuxue
# Processing Record 14 of Set 4 | kalmunai
# Processing Record 15 of Set 4 | leshukonskoye
# Processing Record 16 of Set 4 | ucluelet
# Processing Record 17 of Set 4 | praya
# Processing Record 18 of Set 4 | kaitangata
# Processing Record 19 of Set 4 | beaverlodge
# Processing Record 20 of Set 4 | san carlos
# Processing Record 21 of Set 4 | ancud
# Processing Record 22 of Set 4 | dikson
# Processing Record 23 of Set 4 | shellbrook
# Processing Record 24 of Set 4 | estelle
# Processing Record 25 of Set 4 | asau
# Processing Record 26 of Set 4 | buckingham
# Processing Record 27 of Set 4 | calama
# Processing Record 28 of Set 4 | shetpe
# Processing Record 29 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 4 | ereymentau
# Processing Record 31 of Set 4 | kirakira
# Processing Record 32 of Set 4 | moyale
# Processing Record 33 of Set 4 | riyadh
# Processing Record 34 of Set 4 | arraial do cabo
# Processing Record 35 of Set 4 | ratnagiri
# Processing Record 36 of Set 4 | ocampo
# Processing Record 37 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 38 of Set 4 | vangaindrano
# Processing Record 39 of Set 4 | flin flon
# Processing Record 40 of Set 4 | yeppoon
# Processing Record 41 of Set 4 | nouakchott
# Processing Record 42 of Set 4 | cherskiy
# Processing Record 43 of Set 4 | necochea
# Processing Record 44 of Set 4 | tiksi
# Processing Record 45 of Set 4 | labuhan
# Processing Record 46 of Set 4 | vanavara
# Processing Record 47 of Set 4 | revelstoke
# Processing Record 48 of Set 4 | sorland
# Processing Record 49 of Set 4 | chincha alta
# Processing Record 50 of Set 4 | morondava
# Processing Record 1 of Set 5 | ambulu
# Processing Record 2 of Set 5 | smithers
# Processing Record 3 of Set 5 | khabary
# Processing Record 4 of Set 5 | abu dhabi
# Processing Record 5 of Set 5 | chokurdakh
# Processing Record 6 of Set 5 | srednekolymsk
# Processing Record 7 of Set 5 | kutum
# Processing Record 8 of Set 5 | praia
# Processing Record 9 of Set 5 | shimoda
# Processing Record 10 of Set 5 | vitimskiy
# City not found. Skipping...
# Processing Record 11 of Set 5 | colares
# Processing Record 12 of Set 5 | muzhi
# Processing Record 13 of Set 5 | naze
# Processing Record 14 of Set 5 | rawson
# Processing Record 15 of Set 5 | dingzhou
# Processing Record 16 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 5 | plettenberg bay
# Processing Record 18 of Set 5 | saint-pierre
# Processing Record 19 of Set 5 | lastoursville
# Processing Record 20 of Set 5 | tuktoyaktuk
# Processing Record 21 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 5 | tuatapere
# Processing Record 23 of Set 5 | kapaa
# Processing Record 24 of Set 5 | vostok
# Processing Record 25 of Set 5 | la asuncion
# Processing Record 26 of Set 5 | oktyabrskiy
# Processing Record 27 of Set 5 | bandarbeyla
# Processing Record 28 of Set 5 | vestmannaeyjar
# Processing Record 29 of Set 5 | chak azam sahu
# Processing Record 30 of Set 5 | dolzhanskaya
# Processing Record 31 of Set 5 | carutapera
# Processing Record 32 of Set 5 | fuerte olimpo
# Processing Record 33 of Set 5 | mount gambier
# Processing Record 34 of Set 5 | buraydah
# Processing Record 35 of Set 5 | walvis bay
# Processing Record 36 of Set 5 | san felipe
# Processing Record 37 of Set 5 | la serena
# Processing Record 38 of Set 5 | russell
# Processing Record 39 of Set 5 | saint-leu
# Processing Record 40 of Set 5 | sao joao da barra
# Processing Record 41 of Set 5 | esperance
# Processing Record 42 of Set 5 | san quintin
# Processing Record 43 of Set 5 | thompson
# Processing Record 44 of Set 5 | san lorenzo
# Processing Record 45 of Set 5 | mahe
# Processing Record 46 of Set 5 | kamenka
# Processing Record 47 of Set 5 | xianyang
# Processing Record 48 of Set 5 | ecija
# Processing Record 49 of Set 5 | hay river
# Processing Record 50 of Set 5 | katsuura
# Processing Record 1 of Set 6 | puerto pinasco
# City not found. Skipping...
# Processing Record 2 of Set 6 | barinas
# Processing Record 3 of Set 6 | areosa
# Processing Record 4 of Set 6 | vardo
# Processing Record 5 of Set 6 | bafata
# Processing Record 6 of Set 6 | odda
# Processing Record 7 of Set 6 | kodiak
# Processing Record 8 of Set 6 | paka
# Processing Record 9 of Set 6 | marystown
# Processing Record 10 of Set 6 | bell ville
# Processing Record 11 of Set 6 | swan river
# Processing Record 12 of Set 6 | jining
# Processing Record 13 of Set 6 | alyangula
# Processing Record 14 of Set 6 | canutama
# Processing Record 15 of Set 6 | buala
# Processing Record 16 of Set 6 | san carlos de bariloche
# Processing Record 17 of Set 6 | escarcega
# Processing Record 18 of Set 6 | menongue
# Processing Record 19 of Set 6 | candawaga
# City not found. Skipping...
# Processing Record 20 of Set 6 | havoysund
# Processing Record 21 of Set 6 | tabialan
# City not found. Skipping...
# Processing Record 22 of Set 6 | monrovia
# Processing Record 23 of Set 6 | abha
# Processing Record 24 of Set 6 | ingham
# Processing Record 25 of Set 6 | la plaine
# Processing Record 26 of Set 6 | jiangyou
# Processing Record 27 of Set 6 | kudahuvadhoo
# Processing Record 28 of Set 6 | lata
# Processing Record 29 of Set 6 | santa cruz
# Processing Record 30 of Set 6 | niquero
# Processing Record 31 of Set 6 | port-gentil
# Processing Record 32 of Set 6 | lar gerd
# City not found. Skipping...
# Processing Record 33 of Set 6 | zhaozhou
# Processing Record 34 of Set 6 | lavrentiya
# Processing Record 35 of Set 6 | hobyo
# Processing Record 36 of Set 6 | nanortalik
# Processing Record 37 of Set 6 | kaohsiung
# Processing Record 38 of Set 6 | ilulissat
# Processing Record 39 of Set 6 | tazovskiy
# Processing Record 40 of Set 6 | itacarambi
# Processing Record 41 of Set 6 | kitimat
# Processing Record 42 of Set 6 | nemuro
# Processing Record 43 of Set 6 | zolotinka
# City not found. Skipping...
# Processing Record 44 of Set 6 | ginir
# Processing Record 45 of Set 6 | kruisfontein
# Processing Record 46 of Set 6 | ostrovnoy
# Processing Record 47 of Set 6 | pleshanovo
# Processing Record 48 of Set 6 | souillac
# Processing Record 49 of Set 6 | ambilobe
# Processing Record 50 of Set 6 | anshun
# Processing Record 1 of Set 7 | merke
# Processing Record 2 of Set 7 | timra
# Processing Record 3 of Set 7 | hambantota
# Processing Record 4 of Set 7 | fayaoue
# Processing Record 5 of Set 7 | luorong
# Processing Record 6 of Set 7 | santa isabel do rio negro
# Processing Record 7 of Set 7 | jieshi
# Processing Record 8 of Set 7 | ojinaga
# Processing Record 9 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 10 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 11 of Set 7 | kolyvan
# Processing Record 12 of Set 7 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 7 | canmore
# Processing Record 14 of Set 7 | brae
# Processing Record 15 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 16 of Set 7 | broken hill
# Processing Record 17 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 7 | xapuri
# Processing Record 19 of Set 7 | celestun
# Processing Record 20 of Set 7 | bridgetown
# Processing Record 21 of Set 7 | moussoro
# Processing Record 22 of Set 7 | mackay
# Processing Record 23 of Set 7 | umm lajj
# Processing Record 24 of Set 7 | faya
# Processing Record 25 of Set 7 | sur
# Processing Record 26 of Set 7 | hajnowka
# Processing Record 27 of Set 7 | olafsvik
# Processing Record 28 of Set 7 | salalah
# Processing Record 29 of Set 7 | lahat
# Processing Record 30 of Set 7 | vao
# Processing Record 31 of Set 7 | bay-khaak
# Processing Record 32 of Set 7 | narsaq
# Processing Record 33 of Set 7 | minbu
# Processing Record 34 of Set 7 | luderitz
# Processing Record 35 of Set 7 | fonte boa
# Processing Record 36 of Set 7 | northam
# Processing Record 37 of Set 7 | juegang
# Processing Record 38 of Set 7 | staryy nadym
# Processing Record 39 of Set 7 | arkadelphia
# Processing Record 40 of Set 7 | del rio
# Processing Record 41 of Set 7 | korsakov
# Processing Record 42 of Set 7 | thongwa
# Processing Record 43 of Set 7 | basco
# Processing Record 44 of Set 7 | tsabong
# Processing Record 45 of Set 7 | constitucion
# Processing Record 46 of Set 7 | yalvac
# Processing Record 47 of Set 7 | paradise valley
# Processing Record 48 of Set 7 | turukhansk
# Processing Record 49 of Set 7 | bousse
# Processing Record 50 of Set 7 | ambon
# Processing Record 1 of Set 8 | manoel urbano
# Processing Record 2 of Set 8 | bahia blanca
# Processing Record 3 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 4 of Set 8 | merrill
# Processing Record 5 of Set 8 | eureka
# Processing Record 6 of Set 8 | huilong
# Processing Record 7 of Set 8 | itoman
# Processing Record 8 of Set 8 | kodinsk
# Processing Record 9 of Set 8 | qaqortoq
# Processing Record 10 of Set 8 | salina cruz
# Processing Record 11 of Set 8 | bilma
# Processing Record 12 of Set 8 | betera
# Processing Record 13 of Set 8 | wang saphung
# Processing Record 14 of Set 8 | moissala
# Processing Record 15 of Set 8 | cabo san lucas
# Processing Record 16 of Set 8 | svetlogorsk
# Processing Record 17 of Set 8 | stykkisholmur
# Processing Record 18 of Set 8 | pointe michel
# Processing Record 19 of Set 8 | dordrecht
# Processing Record 20 of Set 8 | belyy yar
# Processing Record 21 of Set 8 | iquitos
# Processing Record 22 of Set 8 | okhotsk
# Processing Record 23 of Set 8 | kosh-agach
# Processing Record 24 of Set 8 | mareeba
# Processing Record 25 of Set 8 | bambous virieux
# Processing Record 26 of Set 8 | almenevo
# City not found. Skipping...
# Processing Record 27 of Set 8 | tigil
# Processing Record 28 of Set 8 | bauska
# Processing Record 29 of Set 8 | spirit river
# Processing Record 30 of Set 8 | watsa
# Processing Record 31 of Set 8 | kampot
# Processing Record 32 of Set 8 | yulara
# Processing Record 33 of Set 8 | gandajika
# Processing Record 34 of Set 8 | verkhoyansk
# Processing Record 35 of Set 8 | lompoc
# Processing Record 36 of Set 8 | dabakala
# Processing Record 37 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 8 | alta floresta
# Processing Record 39 of Set 8 | kollam
# Processing Record 40 of Set 8 | ballarat
# Processing Record 41 of Set 8 | quatre cocos
# Processing Record 42 of Set 8 | ballina
# Processing Record 43 of Set 8 | codrington
# Processing Record 44 of Set 8 | kismayo
# Processing Record 45 of Set 8 | karratha
# Processing Record 46 of Set 8 | saint anthony
# Processing Record 47 of Set 8 | sibolga
# Processing Record 48 of Set 8 | yumen
# Processing Record 49 of Set 8 | leh
# Processing Record 50 of Set 8 | flinders
# Processing Record 1 of Set 9 | batagay
# Processing Record 2 of Set 9 | albertville
# Processing Record 3 of Set 9 | puerto leguizamo
# Processing Record 4 of Set 9 | pachino
# Processing Record 5 of Set 9 | harper
# Processing Record 6 of Set 9 | rodrigues alves
# Processing Record 7 of Set 9 | klaksvik
# Processing Record 8 of Set 9 | iskateley
# Processing Record 9 of Set 9 | zhemchuzhnyy
# City not found. Skipping...
# Processing Record 10 of Set 9 | oros
# Processing Record 11 of Set 9 | yerevan
# Processing Record 12 of Set 9 | saint-ambroise
# Processing Record 13 of Set 9 | coihaique
# Processing Record 14 of Set 9 | anadyr
# Processing Record 15 of Set 9 | namibe
# Processing Record 16 of Set 9 | shagonar
# Processing Record 17 of Set 9 | shamary
# Processing Record 18 of Set 9 | ixtapa
# Processing Record 19 of Set 9 | moron
# Processing Record 20 of Set 9 | isangel
# Processing Record 21 of Set 9 | kollo
# Processing Record 22 of Set 9 | talnakh
# Processing Record 23 of Set 9 | murray bridge
# Processing Record 24 of Set 9 | port macquarie
# Processing Record 25 of Set 9 | nago
# Processing Record 26 of Set 9 | tabou
# Processing Record 27 of Set 9 | monchegorsk
# Processing Record 28 of Set 9 | tahta
# Processing Record 29 of Set 9 | sheopur
# Processing Record 30 of Set 9 | fortuna
# Processing Record 31 of Set 9 | straumen
# Processing Record 32 of Set 9 | koping
# Processing Record 33 of Set 9 | kiama
# Processing Record 34 of Set 9 | touros
# Processing Record 35 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 9 | amuntai
# Processing Record 37 of Set 9 | kalabo
# Processing Record 38 of Set 9 | methoni
# Processing Record 39 of Set 9 | khorramshahr
# Processing Record 40 of Set 9 | pimentel
# Processing Record 41 of Set 9 | acari
# Processing Record 42 of Set 9 | khudumelapye
# Processing Record 43 of Set 9 | concarneau
# Processing Record 44 of Set 9 | khani
# Processing Record 45 of Set 9 | copiapo
# Processing Record 46 of Set 9 | sri aman
# Processing Record 47 of Set 9 | sioux lookout
# Processing Record 48 of Set 9 | kusk
# City not found. Skipping...
# Processing Record 49 of Set 9 | peniche
# Processing Record 50 of Set 9 | kargopol
# Processing Record 1 of Set 10 | lagoa
# Processing Record 2 of Set 10 | sitka
# Processing Record 3 of Set 10 | sinkat
# City not found. Skipping...
# Processing Record 4 of Set 10 | atakpame
# Processing Record 5 of Set 10 | bichura
# Processing Record 6 of Set 10 | larap
# Processing Record 7 of Set 10 | poum
# Processing Record 8 of Set 10 | taoudenni
# Processing Record 9 of Set 10 | nyrob
# Processing Record 10 of Set 10 | taburi
# City not found. Skipping...
# Processing Record 11 of Set 10 | tornio
# Processing Record 12 of Set 10 | ngunguru
# Processing Record 13 of Set 10 | dhidhdhoo
# Processing Record 14 of Set 10 | mezen
# Processing Record 15 of Set 10 | hualmay
# Processing Record 16 of Set 10 | dali
# Processing Record 17 of Set 10 | mount isa
# Processing Record 18 of Set 10 | mitchell
# Processing Record 19 of Set 10 | old shinyanga
# Processing Record 20 of Set 10 | namatanai
# Processing Record 21 of Set 10 | ketchikan
# Processing Record 22 of Set 10 | kloulklubed
# Processing Record 23 of Set 10 | karakendzha
# City not found. Skipping...
# Processing Record 24 of Set 10 | zaranj
# Processing Record 25 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 26 of Set 10 | roald
# Processing Record 27 of Set 10 | ahipara
# Processing Record 28 of Set 10 | puerto carreno
# Processing Record 29 of Set 10 | tulagi
# Processing Record 30 of Set 10 | shieli
# Processing Record 31 of Set 10 | rio grande
# Processing Record 32 of Set 10 | camopi
# Processing Record 33 of Set 10 | nortelandia
# Processing Record 34 of Set 10 | voznesenka
# Processing Record 35 of Set 10 | salta
# Processing Record 36 of Set 10 | ouro preto do oeste
# Processing Record 37 of Set 10 | mazagao
# Processing Record 38 of Set 10 | semenivka
# Processing Record 39 of Set 10 | montepuez
# Processing Record 40 of Set 10 | charters towers
# Processing Record 41 of Set 10 | egvekinot
# Processing Record 42 of Set 10 | bondo
# Processing Record 43 of Set 10 | odweyne
# Processing Record 44 of Set 10 | college
# Processing Record 45 of Set 10 | arman
# Processing Record 46 of Set 10 | paraiso
# Processing Record 47 of Set 10 | jizan
# Processing Record 48 of Set 10 | porto velho
# Processing Record 49 of Set 10 | lerwick
# Processing Record 50 of Set 10 | los llanos de aridane
# Processing Record 1 of Set 11 | port hardy
# Processing Record 2 of Set 11 | durango
# Processing Record 3 of Set 11 | chimbote
# Processing Record 4 of Set 11 | severodvinsk
# Processing Record 5 of Set 11 | geraldton
# Processing Record 6 of Set 11 | tyup
# Processing Record 7 of Set 11 | liverpool
# Processing Record 8 of Set 11 | luanda
# Processing Record 9 of Set 11 | valparaiso
# Processing Record 10 of Set 11 | chapais
# Processing Record 11 of Set 11 | paragominas
# Processing Record 12 of Set 11 | kyela
# Processing Record 13 of Set 11 | orgun
# City not found. Skipping...
# Processing Record 14 of Set 11 | chernyshevskiy
# Processing Record 15 of Set 11 | mizdah
# Processing Record 16 of Set 11 | atar
# Processing Record 17 of Set 11 | anqing
# Processing Record 18 of Set 11 | nurota
# Processing Record 19 of Set 11 | opuwo
# Processing Record 20 of Set 11 | lena
# Processing Record 21 of Set 11 | padang
# Processing Record 22 of Set 11 | vega de alatorre
# Processing Record 23 of Set 11 | oranjemund
# Processing Record 24 of Set 11 | sandila
# Processing Record 25 of Set 11 | baruun-urt
# Processing Record 26 of Set 11 | horta
# Processing Record 27 of Set 11 | vanersborg
# Processing Record 28 of Set 11 | saint george
# Processing Record 29 of Set 11 | bathsheba
# Processing Record 30 of Set 11 | nuristan
# Processing Record 31 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 32 of Set 11 | petropavlovka
# Processing Record 33 of Set 11 | aswan
# Processing Record 34 of Set 11 | keita
# Processing Record 35 of Set 11 | christchurch
# Processing Record 36 of Set 11 | tagusao
# Processing Record 37 of Set 11 | kendari
# Processing Record 38 of Set 11 | lagos
# Processing Record 39 of Set 11 | cukai
# Processing Record 40 of Set 11 | cockburn town
# Processing Record 41 of Set 11 | pilar
# Processing Record 42 of Set 11 | lamu
# Processing Record 43 of Set 11 | kargasok
# Processing Record 44 of Set 11 | kalnciems
# Processing Record 45 of Set 11 | noshiro
# Processing Record 46 of Set 11 | olinda
# Processing Record 47 of Set 11 | abonnema
# Processing Record 48 of Set 11 | bandar-e lengeh
# Processing Record 49 of Set 11 | ocos
# Processing Record 50 of Set 11 | wuning
# Processing Record 1 of Set 12 | calabozo
# Processing Record 2 of Set 12 | pashiya
# Processing Record 3 of Set 12 | presidencia roque saenz pena
# Processing Record 4 of Set 12 | vohibinany
# Processing Record 5 of Set 12 | iralaya
# Processing Record 6 of Set 12 | devarkonda
# Processing Record 7 of Set 12 | baghdad
# Processing Record 8 of Set 12 | koslan
# Processing Record 9 of Set 12 | kiruna
# Processing Record 10 of Set 12 | richards bay
# Processing Record 11 of Set 12 | bilibino
# Processing Record 12 of Set 12 | karamea
# City not found. Skipping...
# Processing Record 13 of Set 12 | sunrise manor
# Processing Record 14 of Set 12 | jalu
# Processing Record 15 of Set 12 | vakhrushev
# Processing Record 16 of Set 12 | kenai
# Processing Record 17 of Set 12 | yantal
# Processing Record 18 of Set 12 | westport
# Processing Record 19 of Set 12 | iqaluit
# Processing Record 20 of Set 12 | suao
# City not found. Skipping...
# Processing Record 21 of Set 12 | nalut
# Processing Record 22 of Set 12 | kafar qasem
# City not found. Skipping...
# Processing Record 23 of Set 12 | tromso
# Processing Record 24 of Set 12 | barabash
# Processing Record 25 of Set 12 | santiago de cuenda
# Processing Record 26 of Set 12 | borovskoy
# Processing Record 27 of Set 12 | rostock
# Processing Record 28 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 12 | lorengau
# Processing Record 30 of Set 12 | zhuhai
# Processing Record 31 of Set 12 | hounde
# Processing Record 32 of Set 12 | kaeo
# Processing Record 33 of Set 12 | rafsanjan
# Processing Record 34 of Set 12 | mucurici
# Processing Record 35 of Set 12 | hit
# Processing Record 36 of Set 12 | fereydun kenar
# Processing Record 37 of Set 12 | ailigandi
# Processing Record 38 of Set 12 | conceicao do araguaia
# Processing Record 39 of Set 12 | bud
# Processing Record 40 of Set 12 | san cristobal
# Processing Record 41 of Set 12 | ankazobe
# Processing Record 42 of Set 12 | corn island
# Processing Record 43 of Set 12 | palmer
# Processing Record 44 of Set 12 | vila
# Processing Record 45 of Set 12 | kingisepp
# Processing Record 46 of Set 12 | coahuayana
# Processing Record 47 of Set 12 | kununurra
# Processing Record 48 of Set 12 | vitim
# Processing Record 49 of Set 12 | mallaig
# Processing Record 50 of Set 12 | saveh
# Processing Record 1 of Set 13 | preobrazheniye
# Processing Record 2 of Set 13 | pringsewu
# Processing Record 3 of Set 13 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 13 | davidson
# Processing Record 5 of Set 13 | stilfontein
# Processing Record 6 of Set 13 | ullal
# Processing Record 7 of Set 13 | osoyoos
# Processing Record 8 of Set 13 | makarska
# Processing Record 9 of Set 13 | vandra
# Processing Record 10 of Set 13 | tulun
# Processing Record 11 of Set 13 | coos bay
# Processing Record 12 of Set 13 | kahului
# Processing Record 13 of Set 13 | phan thiet
# Processing Record 14 of Set 13 | bustamante
# Processing Record 15 of Set 13 | bafq
# Processing Record 16 of Set 13 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 17 of Set 13 | khanna
# Processing Record 18 of Set 13 | ushtobe
# Processing Record 19 of Set 13 | bonavista
# Processing Record 20 of Set 13 | maunabo
# Processing Record 21 of Set 13 | najran
# Processing Record 22 of Set 13 | bulgan
# Processing Record 23 of Set 13 | kachiry
# Processing Record 24 of Set 13 | jutai
# Processing Record 25 of Set 13 | vila velha
# Processing Record 26 of Set 13 | alghero
# Processing Record 27 of Set 13 | kjollefjord
# Processing Record 28 of Set 13 | filadelfia
# Processing Record 29 of Set 13 | mogadishu
# Processing Record 30 of Set 13 | raudeberg
# Processing Record 31 of Set 13 | nizhniy odes
# Processing Record 32 of Set 13 | sampit
# Processing Record 33 of Set 13 | barrhead
# Processing Record 34 of Set 13 | aksha
# Processing Record 35 of Set 13 | nishihara
# Processing Record 36 of Set 13 | nuuk
# Processing Record 37 of Set 13 | lianzhou
# Processing Record 38 of Set 13 | ghanzi
# Processing Record 39 of Set 13 | saba
# Processing Record 40 of Set 13 | te anau
# Processing Record 41 of Set 13 | broome
# Processing Record 42 of Set 13 | mataram
# Processing Record 43 of Set 13 | karasjok
# Processing Record 44 of Set 13 | tabatinga
# Processing Record 45 of Set 13 | acarau
# Processing Record 46 of Set 13 | tarboro
# Processing Record 47 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 48 of Set 13 | ukiah
# Processing Record 49 of Set 13 | ilhabela
# Processing Record 50 of Set 13 | stepnogorsk
# Processing Record 1 of Set 14 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 14 | kapuskasing
# Processing Record 3 of Set 14 | kawana waters
# City not found. Skipping...
# Processing Record 4 of Set 14 | westerland
# Processing Record 5 of Set 14 | zemio
# Processing Record 6 of Set 14 | seymchan
# Processing Record 7 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 8 of Set 14 | piacabucu
# Processing Record 9 of Set 14 | anjiang
# Processing Record 10 of Set 14 | grand forks
# Processing Record 11 of Set 14 | dayong
# Processing Record 12 of Set 14 | raahe
# Processing Record 13 of Set 14 | hongjiang
# Processing Record 14 of Set 14 | cumaribo
# City not found. Skipping...
# Processing Record 15 of Set 14 | les cayes
# Processing Record 16 of Set 14 | muros
# Processing Record 17 of Set 14 | gao
# Processing Record 18 of Set 14 | zhangjiakou
# Processing Record 19 of Set 14 | ijaki
# City not found. Skipping...
# Processing Record 20 of Set 14 | zhigansk
# Processing Record 21 of Set 14 | mus
# Processing Record 22 of Set 14 | mbandaka
# Processing Record 23 of Set 14 | coquimbo
# Processing Record 24 of Set 14 | revyakino
# Processing Record 25 of Set 14 | caibarien
# Processing Record 26 of Set 14 | maceio
# Processing Record 27 of Set 14 | rockland
# Processing Record 28 of Set 14 | koryazhma
# Processing Record 29 of Set 14 | tari
# Processing Record 30 of Set 14 | nioro
# Processing Record 31 of Set 14 | half moon bay
# Processing Record 32 of Set 14 | minusinsk
# Processing Record 33 of Set 14 | edd
# Processing Record 34 of Set 14 | luang prabang
# Processing Record 35 of Set 14 | iracoubo
# Processing Record 36 of Set 14 | przhevalskoye
# Processing Record 37 of Set 14 | rocha
# Processing Record 38 of Set 14 | aberdeen
# Processing Record 39 of Set 14 | boa vista
# Processing Record 40 of Set 14 | lebork
# Processing Record 41 of Set 14 | ewa beach
# Processing Record 42 of Set 14 | srivardhan
# Processing Record 43 of Set 14 | mitu
# Processing Record 44 of Set 14 | sholavandan
# City not found. Skipping...
# Processing Record 45 of Set 14 | grand gaube
# Processing Record 46 of Set 14 | zhob
# Processing Record 47 of Set 14 | aklavik
# Processing Record 48 of Set 14 | kulhudhuffushi
# Processing Record 49 of Set 14 | lantana
# Processing Record 50 of Set 14 | poya
# Processing Record 1 of Set 15 | bariri
# Processing Record 2 of Set 15 | ayan
# Processing Record 3 of Set 15 | urusha
# Processing Record 4 of Set 15 | komsomolskiy
# Processing Record 5 of Set 15 | bintulu
# Processing Record 6 of Set 15 | marienburg
# Processing Record 7 of Set 15 | manzil tamim
# City not found. Skipping...
# Processing Record 8 of Set 15 | mandera
# Processing Record 9 of Set 15 | polson
# Processing Record 10 of Set 15 | jaragua
# Processing Record 11 of Set 15 | yaan
# Processing Record 12 of Set 15 | pacifica
# Processing Record 13 of Set 15 | huarmey
# Processing Record 14 of Set 15 | abu kamal
# Processing Record 15 of Set 15 | ahuimanu
# Processing Record 16 of Set 15 | hailey
# Processing Record 17 of Set 15 | shvartsevskiy
# Processing Record 18 of Set 15 | gaomi
# Processing Record 19 of Set 15 | anchorage
# Processing Record 20 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 21 of Set 15 | tawkar
# City not found. Skipping...
# Processing Record 22 of Set 15 | chulman
# Processing Record 23 of Set 15 | sabang
# Processing Record 24 of Set 15 | suluq
# Processing Record 25 of Set 15 | bambanglipuro
# Processing Record 26 of Set 15 | beloha
# Processing Record 27 of Set 15 | malanje
# Processing Record 28 of Set 15 | saint marys
# Processing Record 29 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 30 of Set 15 | darnah
# Processing Record 31 of Set 15 | ganzhou
# Processing Record 32 of Set 15 | tougan
# Processing Record 33 of Set 15 | catamarca
# Processing Record 34 of Set 15 | aripuana
# Processing Record 35 of Set 15 | sataua
# City not found. Skipping...
# Processing Record 36 of Set 15 | gamba
# Processing Record 37 of Set 15 | bantogon
# Processing Record 38 of Set 15 | nikolsk
# Processing Record 39 of Set 15 | akyab
# Processing Record 40 of Set 15 | lakes entrance
# Processing Record 41 of Set 15 | houma
# Processing Record 42 of Set 15 | kirkland lake
# Processing Record 43 of Set 15 | dunedin
# Processing Record 44 of Set 15 | qarqin
# Processing Record 45 of Set 15 | daru
# Processing Record 46 of Set 15 | hunza
# City not found. Skipping...
# Processing Record 47 of Set 15 | maniitsoq
# Processing Record 48 of Set 15 | gizo
# Processing Record 49 of Set 15 | khor
# Processing Record 50 of Set 15 | orocue
# Processing Record 1 of Set 16 | bangkalan
# Processing Record 2 of Set 16 | ulladulla
# Processing Record 3 of Set 16 | mahon
# Processing Record 4 of Set 16 | las vegas
# Processing Record 5 of Set 16 | galle
# Processing Record 6 of Set 16 | port-cartier
# Processing Record 7 of Set 16 | dalvik
# Processing Record 8 of Set 16 | pochutla
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 697

# %%
#Add the data to a new DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mataura      NZ -46.1927  168.8643     43.68        87          90
# 1    Torrington      US  41.8007  -73.1212     94.41        43          90
# 2  Punta Arenas      CL -53.1500  -70.9167     42.12        70         100
# 3       Vrangel      RU  42.7297  133.0839     54.79        83          13
# 4         Vaini      TO -21.2000 -175.2000     76.41        69          27
# 5       Husavik      IS  66.0449  -17.3389     58.91        60          96
# 6      Brindisi      IT  40.5833   17.6667     73.49        57         100
# 7        Laguna      US  38.4210 -121.4238     89.46        38           1
# 8         Avera      US  33.1940  -82.5271     91.71        41         100
# 9   Clyde River      CA  70.4692  -68.5914     34.66       100         100
#
#    Wind Speed Current Description
# 0        2.26     overcast clouds
# 1        1.99     overcast clouds
# 2        9.75     overcast clouds
# 3        4.92          few clouds
# 4       15.28    scattered clouds
# 5       11.65     overcast clouds
# 6        3.40     overcast clouds
# 7        4.00           clear sky
# 8        4.47     overcast clouds
# 9        1.34          light rain

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
